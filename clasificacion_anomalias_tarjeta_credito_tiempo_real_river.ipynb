# %%
from river import anomaly, stream, compose, datasets, evaluate, metrics, preprocessing

# %% [markdown]
# Set de datos: https://maxhalford.github.io/files/datasets/creditcardfraud.zip

# %%
import pandas as pd 
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.loc[data['Class'] == 1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Proporción de anomalías en el dataset en % del total")
print("----------------------------------------------------")
data['Class'].value_counts(normalize=True)*100
# Out:
# Proporción de anomalías en el dataset en % del total
# ----------------------------------------------------
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64

# %%
data.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
y = data['Class']
x = data.drop('Class', axis = 1)

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
x.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
for xi, yi in stream.iter_pandas(x, y):
    pass

# %%
xi
# Out:
# {'Time': 172792.0,
#  'V1': -0.53341252200504,
#  'V2': -0.189733337002305,
#  'V3': 0.703337366963779,
#  'V4': -0.506271240328258,
#  'V5': -0.0125456787599659,
#  'V6': -0.649616685713792,
#  'V7': 1.57700625437629,
#  'V8': -0.414650407552662,
#  'V9': 0.486179505267237,
#  'V10': -0.915426648905893,
#  'V11': -1.04045833522361,
#  'V12': -0.0315130540252157,
#  'V13': -0.188092900791737,
#  'V14': -0.0843164698151014,
#  'V15': 0.0413334553360658,
#  'V16': -0.302620086427415,
#  'V17': -0.660376645182784,
#  'V18': 0.16742993371973,
#  'V19': -0.256116871098099,
#  'V20': 0.382948104875066,
#  'V21': 0.261057330790975,
#  'V22': 0.643078437820093,
#  'V23': 0.376777014169917,
#  'V24': 0.008797379400242,
#  'V25': -0.473648703898825,
#  'V26': -0.818267121041176,
#  'V27': -0.0024153088000101,
#  'V28': 0.0136489143320671,
#  'Amount': 217.0}

# %%
yi
# Out:
# 0

# %%
from river import imblearn, linear_model

# %% [markdown]
# Usando **undersampling** de la clase mayoritaria para ajustar 80/20 el dataset

# %%
# Usando un modelo de clasificación 'Reg Logística' con undersampling
model_u = (
    preprocessing.StandardScaler() |
    imblearn.RandomUnderSampler(
        classifier = linear_model.LogisticRegression(),
        desired_dist = {0: .8, 1: .2},
        seed = 42
    )
)

# %%
metric = metrics.ROCAUC()

# %%
# %%time 

for xi, yi in stream.iter_pandas(x, y, seed = 100):
    yi_pred = model_u.predict_proba_one(xi) # se itera sobre cada observación 
    model_u.learn_one(xi, yi)               # el modelo se ajusta por cada observación iterada
    metric.update(yi, yi_pred)              # el modelo se actualiza creando 'memoria'
    
# metrica de valoracion
metric
# Out:
# CPU times: total: 18.8 s
# Wall time: 24.9 s
# ROCAUC: 94.75%

# %%
# evaluación global del modelo 'undersampling' de manera progresiva (emulando en producción)
evaluate.progressive_val_score(stream.iter_pandas(x, y), model_u, metric)
# Out:
# ROCAUC: 95.24%

# %%
# evaluación progresiva del modelo a medida que entran nuevos datos

steps = evaluate.iter_progressive_val_score(
    model = model_u,
    dataset = stream.iter_pandas(x, y),
    metric = metric,
    step = 10000      # numero de iteraciones para arrojar el resultado
)

for step in steps:
    print(step)
# Out:
# {'ROCAUC': ROCAUC: 95.40%, 'Step': 10000}
# {'ROCAUC': ROCAUC: 95.53%, 'Step': 20000}
# {'ROCAUC': ROCAUC: 95.46%, 'Step': 30000}
# {'ROCAUC': ROCAUC: 95.50%, 'Step': 40000}
# {'ROCAUC': ROCAUC: 95.68%, 'Step': 50000}
# {'ROCAUC': ROCAUC: 95.60%, 'Step': 60000}
# {'ROCAUC': ROCAUC: 95.60%, 'Step': 70000}
# {'ROCAUC': ROCAUC: 95.62%, 'Step': 80000}
# {'ROCAUC': ROCAUC: 95.69%, 'Step': 90000}
# {'ROCAUC': ROCAUC: 95.59%, 'Step': 100000}
# {'ROCAUC': ROCAUC: 95.48%, 'Step': 110000}
# {'ROCAUC': ROCAUC: 95.42%, 'Step': 120000}
# {'ROCAUC': ROCAUC: 95.47%, 'Step': 130000}
# {'ROCAUC': ROCAUC: 95.44%, 'Step': 140000}
# {'ROCAUC': ROCAUC: 95.49%, 'Step': 150000}
# {'ROCAUC': ROCAUC: 95.64%, 'Step': 160000}
# {'ROCAUC': ROCAUC: 95.65%, 'Step': 170000}
# {'ROCAUC': ROCAUC: 95.66%, 'Step': 180000}
# {'ROCAUC': ROCAUC: 95.69%, 'Step': 190000}
# {'ROCAUC': ROCAUC: 95.64%, 'Step': 200000}
# {'ROCAUC': ROCAUC: 95.64%, 'Step': 210000}
# {'ROCAUC': ROCAUC: 95.56%, 'Step': 220000}
# ...

# %% [markdown]
# Usando **oversampling** de la clase minoritaria -creando datos sintéticos-

# %%
# Usando un modelo de clasificación 'Reg Logística' con oversampling
model_o = (
    preprocessing.StandardScaler() |
    imblearn.RandomOverSampler(
        classifier = linear_model.LogisticRegression(),
        desired_dist = {0: .8, 1: .2},
        seed = 42
    )
)

# %%
# %%time 

for xi, yi in stream.iter_pandas(x, y, seed = 100):
    yi_pred = model_o.predict_proba_one(xi) # se itera sobre cada observación 
    model_o.learn_one(xi, yi)               # el modelo se ajusta por cada observación iterada
    metric.update(yi, yi_pred)              # el modelo se actualiza creando 'memoria'
    
# metrica de valoracion
metric
# Out:
# CPU times: total: 28.1 s
# Wall time: 45.6 s
# ROCAUC: 94.52%

# %%
# evaluación global del modelo 'oversampling' de manera progresiva (emulando en producción)
evaluate.progressive_val_score(stream.iter_pandas(x, y), model_o, metric)
# Out:
# ROCAUC: 94.03%

# %%
# evaluación progresiva del modelo a medida que entran nuevos datos

steps = evaluate.iter_progressive_val_score(
    model = model_o,
    dataset = stream.iter_pandas(x, y),
    metric = metric,
    step = 10000      # numero de iteraciones para arrojar el resultado
)

for step in steps:
    print(step)
# Out:
# {'ROCAUC': ROCAUC: 94.10%, 'Step': 10000}
# {'ROCAUC': ROCAUC: 94.03%, 'Step': 20000}
# {'ROCAUC': ROCAUC: 93.99%, 'Step': 30000}
# {'ROCAUC': ROCAUC: 94.00%, 'Step': 40000}
# {'ROCAUC': ROCAUC: 94.10%, 'Step': 50000}
# {'ROCAUC': ROCAUC: 94.01%, 'Step': 60000}
# {'ROCAUC': ROCAUC: 93.98%, 'Step': 70000}
# {'ROCAUC': ROCAUC: 93.95%, 'Step': 80000}
# {'ROCAUC': ROCAUC: 93.97%, 'Step': 90000}
# {'ROCAUC': ROCAUC: 93.92%, 'Step': 100000}
# {'ROCAUC': ROCAUC: 93.86%, 'Step': 110000}
# {'ROCAUC': ROCAUC: 93.82%, 'Step': 120000}
# {'ROCAUC': ROCAUC: 93.81%, 'Step': 130000}
# {'ROCAUC': ROCAUC: 93.80%, 'Step': 140000}
# {'ROCAUC': ROCAUC: 93.75%, 'Step': 150000}
# {'ROCAUC': ROCAUC: 93.82%, 'Step': 160000}
# {'ROCAUC': ROCAUC: 93.83%, 'Step': 170000}
# {'ROCAUC': ROCAUC: 93.82%, 'Step': 180000}
# {'ROCAUC': ROCAUC: 93.82%, 'Step': 190000}
# {'ROCAUC': ROCAUC: 93.76%, 'Step': 200000}
# {'ROCAUC': ROCAUC: 93.76%, 'Step': 210000}
# {'ROCAUC': ROCAUC: 93.74%, 'Step': 220000}
# ...

# %% [markdown]
# Enfoque híbrido combinando **undersampling** de la categoria mayoritaria y **oversampling** de la minoritaria

# %%
from river import optim

# %%
model_h = (
    preprocessing.StandardScaler() |
    imblearn.RandomUnderSampler(                       # usar undersampler para la categoria mayoritaria
        classifier = linear_model.LogisticRegression(
            loss = optim.losses.Log(weight_pos=5)      # el parámetro 'weight_pos' significa que x5 la clase positiva (oversampling)
        ),
        desired_dist={0: .8, 1: .2},
        seed=42
    )
)

# %%
# %%time

for xi, yi in stream.iter_pandas(x, y, seed = 100):
    yi_pred = model_h.predict_proba_one(xi) # se itera sobre cada observación 
    model_h.learn_one(xi, yi)               # el modelo se ajusta por cada observación iterada
    metric.update(yi, yi_pred)              # el modelo se actualiza creando 'memoria'
    
# metrica de valoracion
metric
# Out:
# CPU times: total: 25.3 s
# Wall time: 29.2 s
# ROCAUC: 94.00%

# %%
# evaluación global del modelo 'hibrido' de manera progresiva (emulando en producción)
evaluate.progressive_val_score(stream.iter_pandas(x, y), model_h, metric)
# Out:
# ROCAUC: 94.23%

# %%
# evaluación progresiva del modelo a medida que entran nuevos datos

steps = evaluate.iter_progressive_val_score(
    model = model_h,
    dataset = stream.iter_pandas(x, y),
    metric = metric,
    step = 10000      # numero de iteraciones para arrojar el resultado
)

for step in steps:
    print(step)
# Out:
# {'ROCAUC': ROCAUC: 94.28%, 'Step': 10000}
# {'ROCAUC': ROCAUC: 94.33%, 'Step': 20000}
# {'ROCAUC': ROCAUC: 94.32%, 'Step': 30000}
# {'ROCAUC': ROCAUC: 94.32%, 'Step': 40000}
# {'ROCAUC': ROCAUC: 94.38%, 'Step': 50000}
# {'ROCAUC': ROCAUC: 94.38%, 'Step': 60000}
# {'ROCAUC': ROCAUC: 94.37%, 'Step': 70000}
# {'ROCAUC': ROCAUC: 94.39%, 'Step': 80000}
# {'ROCAUC': ROCAUC: 94.41%, 'Step': 90000}
# {'ROCAUC': ROCAUC: 94.40%, 'Step': 100000}
# {'ROCAUC': ROCAUC: 94.39%, 'Step': 110000}
# {'ROCAUC': ROCAUC: 94.39%, 'Step': 120000}
# {'ROCAUC': ROCAUC: 94.40%, 'Step': 130000}
# {'ROCAUC': ROCAUC: 94.40%, 'Step': 140000}
# {'ROCAUC': ROCAUC: 94.42%, 'Step': 150000}
# {'ROCAUC': ROCAUC: 94.47%, 'Step': 160000}
# {'ROCAUC': ROCAUC: 94.46%, 'Step': 170000}
# {'ROCAUC': ROCAUC: 94.46%, 'Step': 180000}
# {'ROCAUC': ROCAUC: 94.47%, 'Step': 190000}
# {'ROCAUC': ROCAUC: 94.46%, 'Step': 200000}
# {'ROCAUC': ROCAUC: 94.46%, 'Step': 210000}
# {'ROCAUC': ROCAUC: 94.46%, 'Step': 220000}
# ...
