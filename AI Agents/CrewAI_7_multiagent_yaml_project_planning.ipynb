# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Website Project Tasks Breakdown**
#
# **Project Overview:**
# Objective: Create a website for a small business, ensuring it is visually appealing, user-friendly, and optimized for performance and SEO.
# Timeline: Estimated 12 weeks.
#
# ---
#
# ### Detailed Task Breakdown
#
# 1. **Project Kick-off (Week 1)**
#    - **Scope**: Conduct initial meeting with stakeholders to outline project objectives, deliverables, and timelines.
#    - **Deliverables**: Project kickoff document and initial timeline.
#    - **Dependencies**: None.
#    - **Team Member**: John Doe (Project Manager).
#
# 2. **Research and Requirements Gathering (Weeks 1-2)**
#    - **Scope**: Analyze competitor websites, establish design preferences, gather feedback from business owners.
#    - **Deliverables**: Research report and requirements specification document.
#    - **Dependencies**: Completion of project kick-off.
#    - **Team Members**: John Doe, Bob Smith.
#
# 3. **Wireframe Development (Weeks 2-3)**
#    - **Scope**: Create wireframes for the homepage, "About Us," "Services," "Contact Us," Blog, and Testimonials pages.
#    - **Deliverables**: Wireframe mockups.
#    - **Dependencies**: Completion of requirements gathering.
#    - **Team Member**: Bob Smith.
#
# 4. **Website Design (Weeks 3-5)**
#    - **Scope**: Develop a responsive design for desktop and mobile devices with a modern user interface.
#    - **Deliverables**: High-fidelity design prototypes.
#    - **Dependencies**: Completion of wireframe development.
#    - **Team Member**: Bob Smith.
#
# 5. **Frontend Development (Weeks 5-7)**
#    - **Scope**: Code the website based on approved designs, ensuring responsiveness and user-friendly navigation.
#    - **Deliverables**: Functioning front-end website.
#    - **Dependencies**: Completion of website design.
#    - **Team Member**: Jane Doe.
#
# 6. **Backend Development (Weeks 7-9)**
#    - **Scope**: Set up CMS, integrate database, create necessary APIs for form submissions and blog features.
#    - **Deliverables**: Functional backend.
#    - **Dependencies**: Completion of front-end development.
#    - **Team Member**: Jane Doe.
#
# 7. **Content Creation (Weeks 8-10)**
#    - **Scope**: Write and upload content for "About Us," "Services," "Contact Us," and Blog sections, including setting up testimonials.
#    - **Deliverables**: Completed and published website content.
#    - **Dependencies**: Completion of backend development.
#    - **Team Member**: John Doe, assisted by Bob Smith.
#
# 8. **Search Engine Optimization (Week 10)**
#    - **Scope**: Optimize website content and structure for SEO, ensuring fast loading times.
#    - **Deliverables**: SEO report and optimized website.
#    - **Dependencies**: Completion of content creation.
#    - **Team Member**: Jane Doe.
#
# 9. **Quality Assurance (Week 11)**
#    - **Scope**: Perform testing for bugs, usability issues, and responsiveness on different devices.
#    - **Deliverables**: QA report and bug-fix list.
#    - **Dependencies**: Completion of website build.
#    - **Team Members**: Alice Johnson, Tom Brown.
#
# 10. **Final Adjustments and Deployment (Week 12)**
#     - **Scope**: Implement fixes from QA report and prepare the website for launch.
#     - **Deliverables**: Live website and deployment report.
#     - **Dependencies**: Completion of QA process.
#     - **Team Member**: Jane Doe, with project oversight by John Doe.
#
# 11. **Post-launch Support and Training (Week 12)**
#     - **Scope**: Provide training for business staff on CMS and website management, and address any immediate post-launch issues.
#     - **Deliverables**: Training materials and support documentation.
#     - **Dependencies**: Completion of deployment.
#     - **Team Member**: John Doe, with assistance from Jane Doe.
#
# ---
#
# ### Gantt Chart Visualization
# *Note: Below is a simplified text representation; for actual visualization, a Gantt chart tool or software should be used.*
#
# | Task                                | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 |
# |-------------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|
# | Project Kick-off                    |   X    |        |        |        |        |        |        |        |        |         |         |         |
# | Research and Requirements Gathering  |   X    |   X    |        |        |        |        |        |        |        |         |         |         |
# | Wireframe Development                |        |   X    |   X    |        |        |        |        |        |        |         |         |         |
# | Website Design                       |        |        |   X    |   X    |   X    |        |        |        |        |         |         |         |
# | Frontend Development                 |        |        |        |        |   X    |   X    |   X    |        |        |         |         |         |
# | Backend Development                  |        |        |        |        |        |        |   X    |   X    |   X    |         |         |         |
# | Content Creation                     |        |        |        |        |        |        |        |   X    |   X    |         |         |         |
# | Search Engine Optimization           |        |        |        |        |        |        |        |        |        |    X    |         |         |
# | Quality Assurance                    |        |        |        |        |        |        |        |        |        |         |    X    |         |
# | Final Adjustments and Deployment     |        |        |        |        |        |        |        |        |        |         |         |    X    |
# | Post-launch Support and Training     |        |        |        |        |        |        |        |        |        |         |         |    X    |
#
# ---
#
# **Conclusion:** This comprehensive task breakdown, along with the assignments and timelines, sets the foundation for a successful website project for the small business. Each task is clear, achievable, and strategically sequenced to ensure a smooth workflow. This plan will allow the team to stay aligned and focused, ultimately delivering a high-quality website that meets the needs of the business and its customers.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# **Project Overview:**
# - **Objective:** Create a website for a small business, ensuring it is visually appealing, user-friendly, and optimized for performance and SEO.
# - **Estimated Timeline:** 12 weeks.
#
# ---
#
# ### Task Estimation Breakdown
#
# 1. **Project Kick-off (Week 1)**
#    - **Time/Duration:** 1 day
#    - **Resources:** 1 Project Manager (John Doe)
#    - **Effort Required:** 8 hours
#    - **Risks/Uncertainties:** Low risk; potential for unavailability of stakeholders.
#
# 2. **Research and Requirements Gathering (Weeks 1-2)**
#    - **Time/Duration:** 1 week
#    - **Resources:** 1 Project Manager (John Doe), 1 Analyst (Bob Smith)
#    - **Effort Required:** 40 hours (20 hours each)
#    - **Risks/Uncertainties:** Medium risk; possible delays in feedback from business owners.
#
# 3. **Wireframe Development (Weeks 2-3)**
#    - **Time/Duration:** 1 week
#    - **Resources:** 1 Designer (Bob Smith)
#    - **Effort Required:** 24 hours
#    - **Risks/Uncertainties:** Medium risk; wireframes may need revisions based on stakeholder feedback.
#
# 4. **Website Design (Weeks 3-5)**
#    - **Time/Duration:** 3 weeks
#    - **Resources:** 1 Designer (Bob Smith)
#    - **Effort Required:** 80 hours
#    - **Risks/Uncertainties:** Medium risk; coordination issues if design elements are not aligned with brand.
#
# 5. **Frontend Development (Weeks 5-7)**
#    - **Time/Duration:** 3 weeks
#    - **Resources:** 1 Frontend Developer (Jane Doe)
#    - **Effort Required:** 120 hours
#    - **Risks/Uncertainties:** High risk; time may vary based on complexity of design implementation.
#
# 6. **Backend Development (Weeks 7-9)**
#    - **Time/Duration:** 3 weeks
#    - **Resources:** 1 Backend Developer (Jane Doe)
#    - **Effort Required:** 120 hours
#    - **Risks/Uncertainties:** High risk; unforeseen technical challenges with CMS and database setup.
#
# 7. **Content Creation (Weeks 8-10)**
#    - **Time/Duration:** 2 weeks
#    - **Resources:** 1 Project Manager (John Doe) and 1 Analyst (Bob Smith)
#    - **Effort Required:** 60 hours (40 hours for John, 20 hours for Bob)
#    - **Risks/Uncertainties:** Medium risk; content may need multiple iterations.
#
# 8. **Search Engine Optimization (Week 10)**
#    - **Time/Duration:** 1 week
#    - **Resources:** 1 SEO Specialist (Jane Doe)
#    - **Effort Required:** 20 hours
#    - **Risks/Uncertainties:** Medium risk; potential changes needed based on SEO audit findings.
#
# 9. **Quality Assurance (Week 11)**
#    - **Time/Duration:** 1 week
#    - **Resources:** 2 QA Testers (Alice Johnson, Tom Brown)
#    - **Effort Required:** 40 hours (20 hours each)
#    - **Risks/Uncertainties:** High risk; bugs may require significant time to resolve.
#
# 10. **Final Adjustments and Deployment (Week 12)**
#     - **Time/Duration:** 1 week
#     - **Resources:** 1 Frontend Developer (Jane Doe), 1 Project Manager (John Doe)
#     - **Effort Required:** 40 hours (30 hours for Jane, 10 hours for John)
#     - **Risks/Uncertainties:** Low risk; contingent on successful QA findings.
#
# 11. **Post-launch Support and Training (Week 12)**
#     - **Time/Duration:** 1 week
#     - **Resources:** 1 Project Manager (John Doe) and 1 Frontend Developer (Jane Doe)
#     - **Effort Required:** 20 hours (10 hours each)
#     - **Risks/Uncertainties:** Low risk; short-term issues may arise but can be managed.
#
# ---
#
# ### Summary of Total Estimates
#
# - **Total Time Duration:** 12 weeks
# - **Total Effort Required:** 600 hours
# - **Total Resources:** 6 Team Members
#
# ### Risks & Uncertainties Summary
#
# - Communication delays in feedback and requirements gathering.
# - Potential design modifications based on stakeholder feedback during the wireframing and design phases.
# - Technical challenges may delay backend integration, affecting overall project timelines.
# - Content may require multiple iterations due to alignment with business goals.
# - Post-launch issues could arise, necessitating immediate support and adjustments.
#
# ---
#
# This detailed estimation report provides a comprehensive analysis of the tasks required for the successful completion of the website project. By addressing potential risks and uncertainties, the project team can remain proactive and prepared, ensuring the project's timely and efficient delivery.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                       | Team Member(s)                     | Start Date | End Date   | Effort Required (Hours) |
# |--------------------------------------------|------------------------------------|------------|------------|--------------------------|
# | Project Kick-off                          | John Doe                           | Week 1    | Week 1    | 8                        |
# | Research and Requirements Gathering        | John Doe, Bob Smith                | Week 1    | Week 2    | 40 (20 each)            |
# | Wireframe Development                      | Bob Smith                          | Week 2    | Week 3    | 24                       |
# | Website Design                             | Bob Smith                          | Week 3    | Week 5    | 80                       |
# | Frontend Development                       | Jane Doe                           | Week 5    | Week 7    | 120                      |
# | Backend Development                        | Jane Doe                           | Week 7    | Week 9    | 120                      |
# | Content Creation                           | John Doe, Bob Smith                | Week 8    | Week 10   | 60 (40 John, 20 Bob)    |
# | Search Engine Optimization                 | Jane Doe                           | Week 10   | Week 10   | 20                       |
# | Quality Assurance                          | Alice Johnson, Tom Brown           | Week 11   | Week 11   | 40 (20 each)            |
# | Final Adjustments and Deployment          | Jane Doe, John Doe                 | Week 12   | Week 12   | 40 (30 Jane, 10 John)   |
# | Post-launch Support and Training           | John Doe, Jane Doe                 | Week 12   | Week 12   | 20 (10 each)            |
#
# ### Rationale Behind Allocation Decisions:
#
# 1. **Project Kick-off:** John Doe, as Project Manager, is the best fit to lead the project initiation due to his role in overseeing all project activities.
#
# 2. **Research and Requirements Gathering:** Both John Doe and Bob Smith are assigned to ensure comprehensive gathering of requirements—John for project management and Bob for his analytical skills.
#
# 3. **Wireframe Development:** Bob Smith is the assigned designer for creating wireframes, leveraging his skills specifically in design.
#
# 4. **Website Design:** Bob Smith continues to lead the design phase as he has a strong understanding of the design process and the overall project.
#
# 5. **Frontend Development:** Jane Doe, with her expertise as a software engineer, is tasked with frontend development to translate designs into functional elements.
#
# 6. **Backend Development:** Jane Doe continues into backend development, allowing her to maintain continuity and ownership over the development process given her dual role.
#
# 7. **Content Creation:** This task requires collaboration to craft suitable website content. John Doe will take a leadership role while Bob assists to ensure alignment with project goals.
#
# 8. **Search Engine Optimization:** Jane Doe's experience with SEO will be beneficial as she takes charge of optimizing the website for search engines.
#
# 9. **Quality Assurance:** Given the dual QA Engineer setup with Alice Johnson and Tom Brown, they can effectively share the workload of testing and identifying bugs, which is critical to project success.
#
# 10. **Final Adjustments and Deployment:** Both Jane Doe and John Doe's involvement ensures that the final product meets the requirements and is deployed efficiently.
#
# 11. **Post-launch Support and Training:** Finally, both John Doe and Jane Doe will provide necessary support and user training, ensuring stakeholders are informed and capable.
#
# ### Summary:
#
# The above allocations ensure that each task is assigned to the most suitable team member based on their skills and expertise while distributing the workload efficiently across the team. This strategic approach is aimed at maximizing efficiency and ensuring a successful and timely final delivery of the Website project. By considering individual strengths, overall availability, and ensuring no team member is overburdened, we set the stage for a successful project outcome and satisfied stakeholders.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0028
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         18538          11414               7124                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kick-off',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Research and Requirements Gathering',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe', 'Bob Smith']},
#   {'task_name': 'Wireframe Development',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Website Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Frontend Development',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Backend Development',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Content Creation',
#    'estimated_time_hours': 60.0,
#    'required_resources': ['John Doe', 'Bob Smith']},
#   {'task_name': 'Search Engine Optimization',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Adjustments and Deployment',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'John Doe']},
#   {'task_name': 'Post-launch Support and Training',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe', 'Jane Doe']}],
#  'milestones': [{'milestone_name': 'Project Initiation',
#    'tasks': ['Project Kick-off']},
#   {'milestone_name': 'Requirements Gathering',
#    'tasks': ['Research and Requirements Gathering']},
#   {'milestone_name': 'Design Phase',
#    'tasks': ['Wireframe Development', 'Website Design']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['Frontend Development',
#     'Backend Development',
#     'Content Creation']},
#   {'milestone_name': 'SEO Phase', 'tasks': ['Search Engine Optimization']},
#   {'milestone_name': 'Testing Phase', 'tasks': ['Quality Assurance']},
#   {'milestone_name': 'Deployment Phase',
#    'tasks': ['Final Adjustments and Deployment']},
#   {'milestone_name': 'Support Phase',
#    'tasks': ['Post-launch Support and Training']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_a7b55 th {
#   font-size: 120%;
# }
# #T_a7b55  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_a7b55" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7b55_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_a7b55_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_a7b55_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7b55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7b55_row0_col0" class="data row0 col0" >Project Kick-off</td>
#       <td id="T_a7b55_row0_col1" class="data row0 col1" >8.000000</td>
#       <td id="T_a7b55_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7b55_row1_col0" class="data row1 col0" >Research and Requirements Gathering</td>
#       <td id="T_a7b55_row1_col1" class="data row1 col1" >40.000000</td>
#       <td id="T_a7b55_row1_col2" class="data row1 col2" >['John Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7b55_row2_col0" class="data row2 col0" >Wireframe Development</td>
#       <td id="T_a7b55_row2_col1" class="data row2 col1" >24.000000</td>
#       <td id="T_a7b55_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7b55_row3_col0" class="data row3 col0" >Website Design</td>
#       <td id="T_a7b55_row3_col1" class="data row3 col1" >80.000000</td>
#       <td id="T_a7b55_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7b55_row4_col0" class="data row4 col0" >Frontend Development</td>
#       <td id="T_a7b55_row4_col1" class="data row4 col1" >120.000000</td>
#       <td id="T_a7b55_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7b55_row5_col0" class="data row5 col0" >Backend Development</td>
#       <td id="T_a7b55_row5_col1" class="data row5 col1" >120.000000</td>
#       <td id="T_a7b55_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a7b55_row6_col0" class="data row6 col0" >Content Creation</td>
#       <td id="T_a7b55_row6_col1" class="data row6 col1" >60.000000</td>
#       <td id="T_a7b55_row6_col2" class="data row6 col2" >['John Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a7b55_row7_col0" class="data row7 col0" >Search Engine Optimization</td>
#       <td id="T_a7b55_row7_col1" class="data row7 col1" >20.000000</td>
#       <td id="T_a7b55_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a7b55_row8_col0" class="data row8 col0" >Quality Assurance</td>
#       <td id="T_a7b55_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_a7b55_row8_col2" class="data row8 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a7b55_row9_col0" class="data row9 col0" >Final Adjustments and Deployment</td>
#       <td id="T_a7b55_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_a7b55_row9_col2" class="data row9 col2" >['Jane Doe', 'John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a7b55_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a7b55_row10_col0" class="data row10 col0" >Post-launch Support and Training</td>
#       <td id="T_a7b55_row10_col1" class="data row10 col1" >20.000000</td>
#       <td id="T_a7b55_row10_col2" class="data row10 col2" >['John Doe', 'Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_6cbff th {
#   font-size: 120%;
# }
# #T_6cbff  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_6cbff" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cbff_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_6cbff_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cbff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6cbff_row0_col0" class="data row0 col0" >Project Initiation</td>
#       <td id="T_6cbff_row0_col1" class="data row0 col1" >['Project Kick-off']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6cbff_row1_col0" class="data row1 col0" >Requirements Gathering</td>
#       <td id="T_6cbff_row1_col1" class="data row1 col1" >['Research and Requirements Gathering']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6cbff_row2_col0" class="data row2 col0" >Design Phase</td>
#       <td id="T_6cbff_row2_col1" class="data row2 col1" >['Wireframe Development', 'Website Design']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6cbff_row3_col0" class="data row3 col0" >Development Phase</td>
#       <td id="T_6cbff_row3_col1" class="data row3 col1" >['Frontend Development', 'Backend Development', 'Content Creation']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6cbff_row4_col0" class="data row4 col0" >SEO Phase</td>
#       <td id="T_6cbff_row4_col1" class="data row4 col1" >['Search Engine Optimization']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6cbff_row5_col0" class="data row5 col0" >Testing Phase</td>
#       <td id="T_6cbff_row5_col1" class="data row5 col1" >['Quality Assurance']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6cbff_row6_col0" class="data row6 col0" >Deployment Phase</td>
#       <td id="T_6cbff_row6_col1" class="data row6 col1" >['Final Adjustments and Deployment']</td>
#     </tr>
#     <tr>
#       <th id="T_6cbff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6cbff_row7_col0" class="data row7 col0" >Support Phase</td>
#       <td id="T_6cbff_row7_col1" class="data row7 col1" >['Post-launch Support and Training']</td>
#     </tr>
#   </tbody>
# </table>
