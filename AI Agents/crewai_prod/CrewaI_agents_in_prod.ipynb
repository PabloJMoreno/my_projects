84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 63.35 KiB/774.15 KiB
# ipython    ------------------------------ 14.88 KiB/802.33 KiB
# langchain  ------------------------------ 30.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 46.91 KiB/1.03 MiB
# pygments   ------------------------------ 30.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 48.00 KiB/377.53 KiB
# langchain-core ------------------------------ 46.88 KiB/401.95 KiB
# pydantic   ------------------------------ 109.93 KiB/421.31 KiB
# huggingface-hub ------------------------------ 91.67 KiB/440.10 KiB
# watchfiles ------------------------------ 16.00 KiB/441.97 KiB
# openai     ------------------------------ 48.00 KiB/444.18 KiB
# httptools  ------------------------------ 156.54 KiB/449.01 KiB
# cffi       ------------------------------ 156.88 KiB/456.29 KiB
# trio       ------------------------------ 62.92 KiB/474.92 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 16.00 KiB/502.80 KiB
# mpmath     ------------------------------ 140.41 KiB/523.63 KiB
# greenlet   ------------------------------ 53.38 KiB/588.29 KiB
# chromadb   ------------------------------ 62.91 KiB/613.62 KiB
# pyvis      ------------------------------ 158.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 188.79 KiB/745.07 KiB
# regex      ------------------------------ 175.35 KiB/774.15 KiB
# ipython    ------------------------------ 29.35 KiB/802.33 KiB
# langchain  ------------------------------ 30.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 174.91 KiB/1.03 MiB
# pygments   ------------------------------ 62.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 48.00 KiB/377.53 KiB
# langchain-core ------------------------------ 46.88 KiB/401.95 KiB
# pydantic   ------------------------------ 109.93 KiB/421.31 KiB
# huggingface-hub ------------------------------ 91.67 KiB/440.10 KiB
# watchfiles ------------------------------ 16.00 KiB/441.97 KiB
# openai     ------------------------------ 48.00 KiB/444.18 KiB
# httptools  ------------------------------ 156.54 KiB/449.01 KiB
# cffi       ------------------------------ 156.88 KiB/456.29 KiB
# trio       ------------------------------ 62.92 KiB/474.92 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 16.00 KiB/502.80 KiB
# mpmath     ------------------------------ 140.41 KiB/523.63 KiB
# greenlet   ------------------------------ 53.38 KiB/588.29 KiB
# chromadb   ------------------------------ 62.91 KiB/613.62 KiB
# pyvis      ------------------------------ 158.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 188.79 KiB/745.07 KiB
# regex      ------------------------------ 175.35 KiB/774.15 KiB
# ipython    ------------------------------ 29.35 KiB/802.33 KiB
# langchain  ------------------------------ 30.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 174.91 KiB/1.03 MiB
# pygments   ------------------------------ 62.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 60.69 KiB/377.53 KiB
# langchain-core ------------------------------ 46.88 KiB/401.95 KiB
# pydantic   ------------------------------ 161.24 KiB/421.31 KiB
# huggingface-hub ------------------------------ 214.43 KiB/440.10 KiB
# watchfiles ------------------------------ 224.00 KiB/441.97 KiB
# openai     ------------------------------ 62.37 KiB/444.18 KiB
# httptools  ------------------------------ 204.64 KiB/449.01 KiB
# cffi       ------------------------------ 205.20 KiB/456.29 KiB
# trio       ------------------------------ 134.09 KiB/474.92 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 16.00 KiB/502.80 KiB
# mpmath     ------------------------------ 204.41 KiB/523.63 KiB
# greenlet   ------------------------------ 92.74 KiB/588.29 KiB
# chromadb   ------------------------------ 78.91 KiB/613.62 KiB
# pyvis      ------------------------------ 222.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 237.01 KiB/745.07 KiB
# regex      ------------------------------ 223.35 KiB/774.15 KiB
# ipython    ------------------------------ 94.88 KiB/802.33 KiB
# langchain  ------------------------------ 30.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 218.34 KiB/1.03 MiB
# pygments   ------------------------------ 91.63 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 96.61 KiB/377.53 KiB
# langchain-core ------------------------------ 78.88 KiB/401.95 KiB
# pydantic   ------------------------------ 193.24 KiB/421.31 KiB
# huggingface-hub ------------------------------ 250.01 KiB/440.10 KiB
# watchfiles ------------------------------ 297.81 KiB/441.97 KiB
# openai     ------------------------------ 78.37 KiB/444.18 KiB
# httptools  ------------------------------ 284.64 KiB/449.01 KiB
# cffi       ------------------------------ 269.20 KiB/456.29 KiB
# trio       ------------------------------ 155.56 KiB/474.92 KiB
# pytz       ------------------------------ 62.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 32.00 KiB/502.80 KiB
# mpmath     ------------------------------ 268.41 KiB/523.63 KiB
# greenlet   ------------------------------ 268.74 KiB/588.29 KiB
# chromadb   ------------------------------ 94.91 KiB/613.62 KiB
# pyvis      ------------------------------ 302.04 KiB/738.32 KiB
# pyyaml     ------------------------------ 317.01 KiB/745.07 KiB
# regex      ------------------------------ 319.35 KiB/774.15 KiB
# ipython    ------------------------------ 158.88 KiB/802.33 KiB
# langchain  ------------------------------ 30.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 282.34 KiB/1.03 MiB
# pygments   ------------------------------ 155.74 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 112.61 KiB/377.53 KiB
# langchain-core ------------------------------ 110.88 KiB/401.95 KiB
# pydantic   ------------------------------ 253.93 KiB/421.31 KiB
# huggingface-hub ------------------------------ 319.67 KiB/440.10 KiB
# watchfiles ------------------------------ 368.03 KiB/441.97 KiB
# openai     ------------------------------ 78.37 KiB/444.18 KiB
# httptools  ------------------------------ 364.64 KiB/449.01 KiB
# cffi       ------------------------------ 323.23 KiB/456.29 KiB
# trio       ------------------------------ 235.46 KiB/474.92 KiB
# pytz       ------------------------------ 108.99 KiB/496.10 KiB
# crewai-tools ------------------------------ 48.00 KiB/502.80 KiB
# mpmath     ------------------------------ 351.59 KiB/523.63 KiB
# greenlet   ------------------------------ 348.74 KiB/588.29 KiB
# chromadb   ------------------------------ 366.91 KiB/613.62 KiB
# pyvis      ------------------------------ 382.04 KiB/738.32 KiB
# pyyaml     ------------------------------ 397.01 KiB/745.07 KiB
# regex      ------------------------------ 383.35 KiB/774.15 KiB
# ipython    ------------------------------ 254.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 362.34 KiB/1.03 MiB
# pygments   ------------------------------ 319.63 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 140.69 KiB/377.53 KiB
# langchain-core ------------------------------ 142.88 KiB/401.95 KiB
# pydantic   ------------------------------ 285.93 KiB/421.31 KiB
# huggingface-hub ------------------------------ 335.67 KiB/440.10 KiB
# watchfiles ------------------------------ 441.81 KiB/441.97 KiB
# openai     ------------------------------ 110.26 KiB/444.18 KiB
# httptools  ------------------------------ 428.54 KiB/449.01 KiB
# cffi       ------------------------------ 381.20 KiB/456.29 KiB
# trio       ------------------------------ 303.56 KiB/474.92 KiB
# pytz       ------------------------------ 108.99 KiB/496.10 KiB
# crewai-tools ------------------------------ 77.90 KiB/502.80 KiB
# mpmath     ------------------------------ 412.41 KiB/523.63 KiB
# greenlet   ------------------------------ 412.63 KiB/588.29 KiB
# chromadb   ------------------------------ 366.91 KiB/613.62 KiB
# pyvis      ------------------------------ 448.01 KiB/738.32 KiB
# pyyaml     ------------------------------ 465.49 KiB/745.07 KiB
# regex      ------------------------------ 463.35 KiB/774.15 KiB
# ipython    ------------------------------ 350.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 426.34 KiB/1.03 MiB
# pygments   ------------------------------ 367.63 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# prompt-toolkit ------------------------------ 140.69 KiB/377.53 KiB
# langchain-core ------------------------------ 142.88 KiB/401.95 KiB
# pydantic   ------------------------------ 285.93 KiB/421.31 KiB
# huggingface-hub ------------------------------ 335.67 KiB/440.10 KiB
# openai     ------------------------------ 110.26 KiB/444.18 KiB
# httptools  ------------------------------ 444.54 KiB/449.01 KiB
# cffi       ------------------------------ 397.20 KiB/456.29 KiB
# trio       ------------------------------ 303.56 KiB/474.92 KiB
# pytz       ------------------------------ 108.99 KiB/496.10 KiB
# crewai-tools ------------------------------ 77.90 KiB/502.80 KiB
# mpmath     ------------------------------ 412.41 KiB/523.63 KiB
# greenlet   ------------------------------ 412.63 KiB/588.29 KiB
# chromadb   ------------------------------ 382.91 KiB/613.62 KiB
# pyvis      ------------------------------ 448.01 KiB/738.32 KiB
# pyyaml     ------------------------------ 465.49 KiB/745.07 KiB
# regex      ------------------------------ 479.35 KiB/774.15 KiB
# ipython    ------------------------------ 350.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 442.34 KiB/1.03 MiB
# pygments   ------------------------------ 383.63 KiB/1.17 MiB
# jedi       ------------------------------ 220.70 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# google-cloud-resource-manager ------------------------------     0 B/375.13 KiB
# prompt-toolkit ------------------------------ 140.69 KiB/377.53 KiB
# langchain-core ------------------------------ 158.88 KiB/401.95 KiB
# pydantic   ------------------------------ 308.33 KiB/421.31 KiB
# huggingface-hub ------------------------------ 335.67 KiB/440.10 KiB
# openai     ------------------------------ 126.26 KiB/444.18 KiB
# cffi       ------------------------------ 422.79 KiB/456.29 KiB
# trio       ------------------------------ 303.56 KiB/474.92 KiB
# pytz       ------------------------------ 108.99 KiB/496.10 KiB
# crewai-tools ------------------------------ 317.90 KiB/502.80 KiB
# mpmath     ------------------------------ 460.41 KiB/523.63 KiB
# greenlet   ------------------------------ 444.63 KiB/588.29 KiB
# chromadb   ------------------------------ 382.91 KiB/613.62 KiB
# pyvis      ------------------------------ 478.04 KiB/738.32 KiB
# pyyaml     ------------------------------ 513.49 KiB/745.07 KiB
# regex      ------------------------------ 511.35 KiB/774.15 KiB
# ipython    ------------------------------ 350.88 KiB/802.33 KiB
# langchain  ------------------------------ 46.91 KiB/985.56 KiB
# tiktoken   ------------------------------ 474.34 KiB/1.03 MiB
# pygments   ------------------------------ 399.63 KiB/1.17 MiB
# jedi       ------------------------------ 224.30 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/232)
# rpds-py    ------------------------------ 16.00 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 16.00 KiB/375.13 KiB
# prompt-toolkit ------------------------------
04 KiB/738.32 KiB
# pyyaml     ------------------------------ 733.01 KiB/745.07 KiB
# regex      ------------------------------ 735.24 KiB/774.15 KiB
# ipython    ------------------------------ 568.56 KiB/802.33 KiB
# langchain  ------------------------------ 123.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 682.12 KiB/1.03 MiB
# pygments   ------------------------------ 655.63 KiB/1.17 MiB
# jedi       ------------------------------ 268.89 KiB/1.50 MiB
# aiohttp    ------------------------------ 702.22 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/232)
# pytest     ------------------------------ 31.89 KiB/335.04 KiB
# yarl       ------------------------------ 85.88 KiB/336.08 KiB
# jiter      ------------------------------ 94.61 KiB/337.45 KiB
# tzdata     ------------------------------ 78.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 175.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 221.58 KiB/375.13 KiB
# langchain-core ------------------------------ 382.08 KiB/401.95 KiB
# openai     ------------------------------ 238.37 KiB/444.18 KiB
# pytz       ------------------------------ 157.59 KiB/496.10 KiB
# chromadb   ------------------------------ 494.91 KiB/613.62 KiB
# pyvis      ------------------------------ 670.04 KiB/738.32 KiB
# pyyaml     ------------------------------ 733.01 KiB/745.07 KiB
# regex      ------------------------------ 735.24 KiB/774.15 KiB
# ipython    ------------------------------ 600.56 KiB/802.33 KiB
# langchain  ------------------------------ 123.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 682.12 KiB/1.03 MiB
# pygments   ------------------------------ 671.63 KiB/1.17 MiB
# jedi       ------------------------------ 268.89 KiB/1.50 MiB
# aiohttp    ------------------------------ 702.22 KiB/1.60 MiB
# networkx   ------------------------------ 403.37 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/232)
# pytest     ------------------------------ 31.89 KiB/335.04 KiB
# yarl       ------------------------------ 85.88 KiB/336.08 KiB
# jiter      ------------------------------ 94.61 KiB/337.45 KiB
# tzdata     ------------------------------ 78.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 175.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 221.58 KiB/375.13 KiB
# openai     ------------------------------ 238.37 KiB/444.18 KiB
# pytz       ------------------------------ 157.59 KiB/496.10 KiB
# chromadb   ------------------------------ 494.91 KiB/613.62 KiB
# pyvis      ------------------------------ 670.04 KiB/738.32 KiB
# pyyaml     ------------------------------ 733.01 KiB/745.07 KiB
# regex      ------------------------------ 735.24 KiB/774.15 KiB
# ipython    ------------------------------ 616.56 KiB/802.33 KiB
# langchain  ------------------------------ 123.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 682.12 KiB/1.03 MiB
# pygments   ------------------------------ 671.63 KiB/1.17 MiB
# jedi       ------------------------------ 268.89 KiB/1.50 MiB
# aiohttp    ------------------------------ 702.22 KiB/1.60 MiB
# networkx   ------------------------------ 419.37 KiB/1.64 MiB
# kubernetes ------------------------------ 640.47 KiB/1.77 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/232)
# pytest     ------------------------------ 47.89 KiB/335.04 KiB
# yarl       ------------------------------ 101.88 KiB/336.08 KiB
# jiter      ------------------------------ 110.61 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 175.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 221.58 KiB/375.13 KiB
# openai     ------------------------------ 254.37 KiB/444.18 KiB
# pytz       ------------------------------ 173.59 KiB/496.10 KiB
# chromadb   ------------------------------ 526.91 KiB/613.62 KiB
# pyvis      ------------------------------ 702.04 KiB/738.32 KiB
# pyyaml     ------------------------------ 733.01 KiB/745.07 KiB
# regex      ------------------------------ 735.24 KiB/774.15 KiB
# ipython    ------------------------------ 648.56 KiB/802.33 KiB
# langchain  ------------------------------ 139.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 698.12 KiB/1.03 MiB
# pygments   ------------------------------ 703.63 KiB/1.17 MiB
# jedi       ------------------------------ 282.01 KiB/1.50 MiB
# aiohttp    ------------------------------ 734.22 KiB/1.60 MiB
# networkx   ------------------------------ 451.37 KiB/1.64 MiB
# kubernetes ------------------------------ 670.05 KiB/1.77 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/232)
# bcrypt     ------------------------------     0 B/272.08 KiB
# pypdf      ------------------------------     0 B/290.99 KiB
# langsmith  ------------------------------ 14.91 KiB/304.50 KiB
# protobuf   ------------------------------ 62.91 KiB/312.18 KiB
# weaviate-client ------------------------------     0 B/317.74 KiB
# pytest     ------------------------------ 63.60 KiB/335.04 KiB
# yarl       ------------------------------ 165.88 KiB/336.08 KiB
# jiter      ------------------------------ 174.61 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 223.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 237.58 KiB/375.13 KiB
# openai     ------------------------------ 254.37 KiB/444.18 KiB
# pytz       ------------------------------ 189.59 KiB/496.10 KiB
# chromadb   ------------------------------ 542.91 KiB/613.62 KiB
# pyvis      ------------------------------ 734.04 KiB/738.32 KiB
# regex      ------------------------------ 774.15 KiB/774.15 KiB
# ipython    ------------------------------ 655.45 KiB/802.33 KiB
# langchain  ------------------------------ 139.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 731.31 KiB/1.03 MiB
# pygments   ------------------------------ 735.63 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/232)
# bcrypt     ------------------------------ 16.00 KiB/272.08 KiB
# pypdf      ------------------------------ 14.92 KiB/290.99 KiB
# langsmith  ------------------------------ 14.91 KiB/304.50 KiB
# protobuf   ------------------------------ 62.91 KiB/312.18 KiB
# weaviate-client ------------------------------ 14.91 KiB/317.74 KiB
# pytest     ------------------------------ 79.60 KiB/335.04 KiB
# yarl       ------------------------------ 181.88 KiB/336.08 KiB
# jiter      ------------------------------ 194.39 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 255.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 253.58 KiB/375.13 KiB
# openai     ------------------------------ 254.37 KiB/444.18 KiB
# pytz       ------------------------------ 189.59 KiB/496.10 KiB
# chromadb   ------------------------------ 542.91 KiB/613.62 KiB
# pyvis      ------------------------------ 734.04 KiB/738.32 KiB
# ipython    ------------------------------ 655.45 KiB/802.33 KiB
# langchain  ------------------------------ 139.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 763.31 KiB/1.03 MiB
# pygments   ------------------------------ 751.63 KiB/1.17 MiB
# jedi       ------------------------------ 282.01 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/232)
# qdrant-client ------------------------------     0 B/260.91 KiB
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------ 76.96 KiB/272.08 KiB
# pypdf      ------------------------------ 53.69 KiB/290.99 KiB
# langsmith  ------------------------------ 14.91 KiB/304.50 KiB
# protobuf   ------------------------------ 108.84 KiB/312.18 KiB
# weaviate-client ------------------------------ 14.91 KiB/317.74 KiB
# pytest     ------------------------------ 111.60 KiB/335.04 KiB
# yarl       ------------------------------ 229.88 KiB/336.08 KiB
# jiter      ------------------------------ 242.28 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 287.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 269.58 KiB/375.13 KiB
# openai     ------------------------------ 254.37 KiB/444.18 KiB
# pytz       ------------------------------ 189.59 KiB/496.10 KiB
# chromadb   ------------------------------ 558.91 KiB/613.62 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# ipython    ------------------------------ 671.45 KiB/802.33 KiB
# langchain  ------------------------------ 139.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 810.34 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/232)
# qdrant-client ------------------------------     0 B/260.91 KiB
# frozenlist ------------------------------     0 B/268.43 KiB
# bcrypt     ------------------------------ 76.96 KiB/272.08 KiB
# pypdf      ------------------------------ 69.69 KiB/290.99 KiB
# langsmith  ------------------------------ 14.91 KiB/304.50 KiB
# protobuf   ------------------------------ 108.84 KiB/312.18 KiB
# weaviate-client ------------------------------ 14.91 KiB/317.74 KiB
# pytest     ------------------------------ 111.60 KiB/335.04 KiB
# yarl       ------------------------------ 229.88 KiB/336.08 KiB
# jiter      ------------------------------ 242.28 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 287.41 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 269.58 KiB/375.13 KiB
# openai     ------------------------------ 254.37 KiB/444.18 KiB
# pytz       ------------------------------ 189.59 KiB/496.10 KiB
# chromadb   ------------------------------ 558.91 KiB/613.62 KiB
# ipython    ------------------------------ 671.45 KiB/802.33 KiB
# langchain  ------------------------------ 139.95 KiB/985.56 KiB
# tiktoken   ------------------------------ 810.34 KiB/1.03 MiB
# pygments   ------------------------------ 783.63 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/232)
# openpyxl   ------------------------------ 32.00 KiB/245.03 KiB
# qdrant-client ------------------------------ 64.00 KiB/260.91 KiB
# frozenlist ------------------------------ 92.74 KiB/268.43 KiB
# bcrypt     ------------------------------ 158.35 KiB/272.08 KiB
# pypdf      ------------------------------ 128.64 KiB/290.99 KiB
# langsmith  ------------------------------ 110.91 KiB/304.50 KiB
# protobuf   ------------------------------ 172.84 KiB/312.18 KiB
# weaviate-client ------------------------------ 46.80 KiB/317.74 KiB
# pytest     ------------------------------ 223.60 KiB/335.04 KiB
# yarl       ------------------------------ 298.69 KiB/336.08 KiB
# jiter      ------------------------------ 334.61 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 366.23 KiB/372.36 KiB
# google-cloud-resource-manager ------------------------------ 365.58 KiB/375.13 KiB
# openai     ------------------------------ 270.37 KiB/444.18 KiB
# pytz       ------------------------------ 205.59 KiB/496.10 KiB
# chromadb   ------------------------------ 580.34 KiB/613.62 KiB
# ipython    ------------------------------ 703.45 KiB/802.33 KiB
# langchain  ------------------------------ 155.73 KiB/985.56 KiB
# tiktoken   ------------------------------ 859.75 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/232)
# openpyxl   ------------------------------ 32.00 KiB/245.03 KiB
# qdrant-client ------------------------------ 80.00 KiB/260.91 KiB
# frozenlist ------------------------------ 108.74 KiB/268.43 KiB
# bcrypt     ------------------------------ 174.35 KiB/272.08 KiB
# pypdf      ------------------------------ 142.92 KiB/290.99 KiB
# langsmith  ------------------------------ 206.91 KiB/304.50 KiB
# protobuf   ------------------------------ 188.84 KiB/312.18 KiB
# weaviate-client ------------------------------ 46.80 KiB/317.74 KiB
# pytest     ------------------------------ 238.54 KiB/335.04 KiB
# yarl       ------------------------------ 309.88 KiB/336.08 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# rpds-py    ------------------------------ 372.36 KiB/372.36 KiB
# openai     ------------------------------ 286.37 KiB/444.18 KiB
# pytz       ------------------------------ 205.59 KiB/496.10 KiB
# chromadb   ------------------------------ 580.34 KiB/613.62 KiB
# ipython    ------------------------------ 712.56 KiB/802.33 KiB
# langchain  ------------------------------ 171.73 KiB/985.56 KiB
# tiktoken   ------------------------------ 891.75 KiB/1.03 MiB
# pygments   ------------------------------ 895.63 KiB/1.17 MiB
# jedi       ------------------------------ 298.01 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/232)
# openpyxl   ------------------------------ 32.00 KiB/245.03 KiB
# qdrant-client ------------------------------ 80.00 KiB/260.91 KiB
# frozenlist ------------------------------ 124.74 KiB/268.43 KiB
# bcrypt     ------------------------------ 174.35 KiB/272.08 KiB
# pypdf      ------------------------------ 158.92 KiB/290.99 KiB
# langsmith  ------------------------------ 206.91 KiB/304.50 KiB
# protobuf   ------------------------------ 204.84 KiB/312.18 KiB
# weaviate-client ------------------------------ 46.80 KiB/317.74 KiB
# pytest     ------------------------------ 238.54 KiB/335.04 KiB
# yarl       ------------------------------ 309.88 KiB/336.08 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# tzdata     ------------------------------ 94.69 KiB/338.46 KiB
# openai     ------------------------------ 286.37 KiB/444.18 KiB
# pytz       ------------------------------ 205.59 KiB/496.10 KiB
# chromadb   ------------------------------ 580.34 KiB/613.62 KiB
# ipython    ------------------------------ 712.56 KiB/802.33 KiB
# langchain  ------------------------------ 171.73 KiB/985.56 KiB
# tiktoken   ------------------------------ 891.75 KiB/1.03 MiB
# pygments   ------------------------------ 895.63 KiB/1.17 MiB
# jedi       ------------------------------ 298.01 KiB/1.50 MiB
# aiohttp    ------------------------------ 974.22 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (13/232)
# openpyxl   ------------------------------ 32.00 KiB/245.03 KiB
# qdrant-client ------------------------------ 80.00 KiB/260.91 KiB
# ...
# uv         ------------------------------ 14.03 MiB/15.00 MiB
# numpy      ------------------------------ 12.81 MiB/17.41 MiB
# lancedb    ------------------------------ 14.30 MiB/28.54 MiB
# pylance    ------------------------------ 13.05 MiB/31.92 MiB
# ⠇ Preparing packages... (223/232) 14.07 MiB/38.22 MiB
# jedi       ------------------------------ 1.21 MiB/1.50 MiB
# selenium   ------------------------------ 9.23 MiB/9.26 MiB
# pandas     ------------------------------ 12.06 MiB/12.45 MiB
# onnxruntime ------------------------------ 12
# lancedb    ------------------------------ 21.97 MiB/28.54 MiB
# pylance    ------------------------------ 20.62 MiB/31.92 MiB
# ⠸ Preparing packages... (229/232) 18.53 MiB/38.22 MiB
# lancedb    ------------------------------ 22.03 MiB/28.54 MiB
# pylance    ------------------------------ 20.62 MiB/31.92 MiB
# ⠸ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 22.05 MiB/28.54 MiB
# pylance    ------------------------------ 20.62 MiB/31.92 MiB
# ⠼ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 24.09 MiB/28.54 MiB
# pylance    ------------------------------ 21.00 MiB/31.92 MiB
# ⠼ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 24.09 MiB/28.54 MiB
# pylance    ------------------------------ 21.05 MiB/31.92 MiB
# ⠼ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 24.09 MiB/28.54 MiB
# pylance    ------------------------------ 21.06 MiB/31.92 MiB
# ⠼ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 24.09 MiB/28.54 MiB
# pylance    ------------------------------ 21.06 MiB/31.92 MiB
# ⠼ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 24.09 MiB/28.54 MiB
# pylance    ------------------------------ 22.67 MiB/31.92 MiB
# ⠴ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 27.07 MiB/28.54 MiB
# pylance    ------------------------------ 24.57 MiB/31.92 MiB
# ⠴ Preparing packages... (229/232) 18.85 MiB/38.22 MiB
# lancedb    ------------------------------ 27.97 MiB/28.54 MiB
# pylance    ------------------------------ 25.98 MiB/31.92 MiB
# ⠦ Preparing packages... (229/232) 21.20 MiB/38.22 MiB
# lancedb    ------------------------------ 28.15 MiB/28.54 MiB
# pylance    ------------------------------ 27.26 MiB/31.92 MiB
# ⠦ Preparing packages... (229/232) 22.69 MiB/38.22 MiB
# lancedb    ------------------------------ 28.15 MiB/28.54 MiB
# pylance    ------------------------------ 27.30 MiB/31.92 MiB
# ⠦ Preparing packages... (229/232) 22.69 MiB/38.22 MiB
# lancedb    ------------------------------ 28.15 MiB/28.54 MiB
# pylance    ------------------------------ 29.09 MiB/31.92 MiB
# ⠦ Preparing packages... (229/232) 22.69 MiB/38.22 MiB
# pylance    ------------------------------ 31.87 MiB/31.92 MiB
# ⠦ Preparing packages... (229/232) 22.69 MiB/38.22 MiB
# ⠦ Preparing packages... (229/232) 22.69 MiB/38.22 MiB
# ⠦ Preparing packages... (229/232) 22.71 MiB/38.22 MiB
# ⠧ Preparing packages... (231/232) 24.45 MiB/38.22 MiB
# ⠧ Preparing packages... (231/232) 28.14 MiB/38.22 MiB
# ⠧ Preparing packages... (231/232) 31.31 MiB/38.22 MiB
# ⠧ Preparing packages... (231/232) 31.43 MiB/38.22 MiB
# ⠧ Preparing packages... (231/232) 31.93 MiB/38.22 MiB
# ⠇ Preparing packages... (231/232) 36.15 MiB/38.22 MiB
# Prepared 232 packages in 6.88s
# Installed 232 packages in 195ms
#  + aiohappyeyeballs==2.4.4
#  + aiohttp==3.11.11
#  + aiosignal==1.3.2
#  + alembic==1.14.0
#  + annotated-types==0.7.0
#  + anyio==4.8.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==24.3.0
#  + auth0-python==4.7.2
#  + authlib==1.3.1
#  + backoff==2.2.1
#  + bcrypt==4.2.1
#  + beautifulsoup4==4.12.3
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.0
#  + certifi==2024.12.14
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.13.6
#  + coloredlogs==15.0.1
#  + crewai==0.95.0
#  + crewai-tools==0.25.8
#  + cryptography==43.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.15
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + docx2txt==0.8
#  + durationpy==0.9
#  + embedchain==0.1.126
#  + et-xmlfile==2.0.0
#  + executing==2.1.0
#  + fastapi==0.115.6
#  + fastavro==1.10.0
#  + filelock==3.16.1
#  + flatbuffers==24.12.23
#  + frozenlist==1.5.0
#  + fsspec==2024.12.0
#  + google-api-core==2.24.0
#  + google-auth==2.37.0
#  + google-cloud-aiplatform==1.76.0
#  + google-cloud-bigquery==3.27.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.14.0
#  + google-cloud-storage==2.19.0
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.66.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.14.0
#  + grpcio==1.69.0
#  + grpcio-health-checking==1.69.0
#  + grpcio-status==1.69.0
#  + grpcio-tools==1.69.0
#  + h11==0.14.0
#  + h2==4.1.0
#  + hpack==4.0.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.27.1
#  + humanfriendly==10.0
#  + hyperframe==6.0.1
#  + idna==3.10
#  + ijson==3.3.0
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.5.2
#  + iniconfig==2.0.0
#  + instructor==1.7.2
#  + ipython==8.31.0
#  + jedi==0.19.2
#  + jinja2==3.1.5
#  + jiter==0.8.2
#  + json-repair==0.35.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.1
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==31.0.0
#  + lancedb==0.17.0
#  + langchain==0.3.14
#  + langchain-cohere==0.3.4
#  + langchain-community==0.3.14
#  + langchain-core==0.3.29
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.5
#  + langsmith==0.1.147
#  + linkup-sdk==0.2.2
#  + litellm==1.58.0
#  + mako==1.3.8
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.25.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.43
#  + mmh3==5.0.1
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.1
#  + openai==1.59.7
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.29.0
#  + opentelemetry-exporter-otlp-proto-common==1.29.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.29.0
#  + opentelemetry-exporter-otlp-proto-http==1.29.0
#  + opentelemetry-instrumentation==0.50b0
#  + opentelemetry-instrumentation-asgi==0.50b0
#  + opentelemetry-instrumentation-fastapi==0.50b0
#  + opentelemetry-proto==1.29.0
#  + opentelemetry-sdk==1.29.0
#  + opentelemetry-semantic-conventions==0.50b0
#  + opentelemetry-util-http==0.50b0
#  + orjson==3.10.14
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parameterized==0.9.0
#  + parso==0.8.4
#  + pdfminer-six==20231228
#  + pdfplumber==0.11.5
#  + pexpect==4.9.0
#  + pillow==11.1.0
#  + pluggy==1.5.0
#  + portalocker==2.10.1
#  + posthog==3.7.5
#  + prompt-toolkit==3.0.48
#  + propcache==0.2.1
#  + proto-plus==1.25.0
#  + protobuf==5.29.3
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==18.1.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.10.5
#  + pydantic-core==2.27.2
#  + pydantic-settings==2.7.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pylance==0.20.0
#  + pypdf==5.1.0
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.391
#  + pysbd==0.3.4
#  + pysocks==1.7.1
#  + pytest==8.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.12.2
#  + referencing==0.35.1
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.22.3
#  + rsa==4.9
#  + schema==0.7.7
#  + scrapegraph-py==1.9.0
#  + selenium==4.27.1
#  + serpapi==0.1.5
#  + setuptools==75.8.0
#  + shapely==2.0.6
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + sortedcontainers==2.4.0
#  + soupsieve==2.6
#  + spider-client==0.1.25
#  + sqlalchemy==2.0.37
#  + stack-data==0.6.3
#  + starlette==0.41.3
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.1.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + trio==0.28.0
#  + trio-websocket==0.11.1
#  + typer==0.15.1
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2024.2
#  + urllib3==2.3.0
#  + uv==0.5.18
#  + uvicorn==0.34.0
#  + uvloop==0.21.0
#  + validators==0.34.0
#  + watchfiles==1.0.4
#  + wcwidth==0.2.13
#  + weaviate-client==4.10.2
#  + websocket-client==1.8.0
#  + websockets==14.1
#  + wrapt==1.17.1
#  + wsproto==1.2.0
#  + yarl==1.18.3
#  + zipp==3.21.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Model Efficiency Improvements**: Recent advancements have focused on optimizing transformer architectures, significantly enhancing computational efficiency without sacrificing performance. Techniques such as Sparse Transformers and mixture of experts (MoE) are gaining traction, allowing larger models to be deployed with reduced resource requirements.
#
# 2. **Multimodal Capabilities**: AI LLMs are increasingly being integrated with other modalities (like images and audio) to create multimodal AI systems. Models such as OpenAI’s DALL-E and CLIP are examples of how natural language processing can be combined with visual understanding, expanding the uses of LLMs in more complex applications.
#
# 3. **Self-Supervised Learning Techniques**: Innovations in self-supervised learning approaches have paved the way for models that require significantly less labeled data. Techniques such as contrastive learning and masked language modeling are driving the development of next-gen LLMs, making them not only effective but more accessible.
#
# 4. **Ethics and Bias Mitigation**: As LLMs continue to evolve, addressing ethical concerns around bias and fairness is becoming a key focus. Researchers are developing methods to identify and mitigate biases in training datasets and model outputs, striving to promote equitable AI systems.
#
# 5. **Increased Adoption in Industry**: Businesses are leveraging AI LLMs for various applications ranging from customer service to content generation and data analysis. Companies are integrating these models into their operations to enhance productivity and streamline processes, signaling a shift towards more AI-driven decision-making.
#
# 6. **Continual Learning**: New architectures are being explored that enable models to learn continuously from new data while retaining knowledge from previous learning episodes. This insight-driven approach reduces the retraining cost and enhances adaptability to changing environments.
#
# 7. **Environmental Impact Consideration**: The AI community is placing greater emphasis on the ecological footprint of training large language models. Efforts are being made to improve energy efficiency through methods like knowledge distillation and model pruning, alongside exploring carbon credits and off-setting strategies.
#
# 8. **Open Source Movement**: The rise of open-source LLMs, such as Hugging Face's Transformers and EleutherAI’s GPT-Neo, is democratizing access to robust natural language processing capabilities. This shift is encouraging collaboration and innovation in the AI field, allowing researchers and developers around the globe to contribute.
#
# 9. **Regulatory Developments**: The rapid deployment of LLMs has resulted in growing scrutiny from regulatory bodies. Governments are beginning to draft guidelines and regulations focusing on the ethical use of AI, data privacy, and transparency, urging companies to be accountable for the AI systems they deploy.
#
# 10. **Human-AI Collaboration**: New models are designed to facilitate collaboration between humans and AI, refining the way AI tools assist in creative tasks, decision-making, and problem-solving. This trend highlights the potential for LLMs to augment human capabilities, rather than just automate processes.
#
# By synthesizing these developments, we can see that the landscape of AI LLMs is rapidly evolving, with significant implications for technology, ethics, industries, and society at large.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Detailed Report on the Evolving Landscape of AI LLMs
#
# ## 1. Model Efficiency Improvements
#
# Recent advancements in AI language models have placed a significant emphasis on optimizing transformer architectures. These enhancements aim to achieve computational efficiency without compromising performance. Techniques such as Sparse Transformers allow for intelligent pruning of less critical components within networks, resulting in reduced computational workloads. The mixture of experts (MoE) model is another innovative approach that facilitates the dynamic allocation of resources, allowing only the most relevant models to be activated for specific tasks. This combination of technologies is leading to the deployment of larger models within lower resource environments. The benefits are twofold: not only do organizations save on operational costs, but they also gain the capability to handle more complex tasks which were previously limited by computational constraints.
#
# ## 2. Multimodal Capabilities
#
# The integration of multiple modalities—most notably images and audio—into AI large language models is a burgeoning area of research. Multimodal systems enhance the capability of LLMs, allowing them to interpret and generate responses that involve more than just text. OpenAI’s DALL-E, which generates images from textual descriptions, and CLIP that combines natural language processing with visual understanding, are prime examples. These technological strides demonstrate the potential of LLMs to engage in complex applications such as automatic content creation, online education, and sophisticated human-computer interaction, where understanding context from diverse input types is crucial.
#
# ## 3. Self-Supervised Learning Techniques
#
# Self-supervised learning techniques have revolutionized the training of AI models, minimizing the need for labeled data. Innovations such as contrastive learning and masked language modeling are reshaping the landscape by allowing models to learn from vast amounts of unstructured data. In contrastive learning, models differentiate between similar and dissimilar examples, honing their ability to discern subtle nuances in data. Masked language modeling, which conceals portions of input text for the model to predict, encourages a deeper understanding of language structure and context. As a result, these methods lead to the development of next-generation LLMs that are more efficient, powerful, and accessible to a broader audience.
#
# ## 4. Ethics and Bias Mitigation
#
# As the capabilities of LLMs evolve, so too do the ethical concerns regarding their use. Research is increasingly focusing on identifying and mitigating biases in both training datasets and model outputs. The objective is to ensure fair and equitable AI systems that do not perpetuate existing social inequalities. Techniques include diversified training data, algorithmic audits, and sensitivity analyses to examine how LLM outputs can vary based on input diversity. The development of frameworks for ethical guidelines is crucial for guiding organizations in the responsible development and deployment of AI technologies, thereby fostering public trust and social responsibility.
#
# ## 5. Increased Adoption in Industry
#
# AI LLMs have witnessed accelerated adoption across various industries, revolutionizing processes from customer service to content generation and data analysis. Companies are embedding these models into their operations as a means to enhance productivity and streamline various processes. For instance, chatbots powered by LLMs can manage customer queries with increased efficiency, while content generation algorithms assist marketers in producing tailored content at scale. This widespread integration signals a transformative shift toward more AI-driven decision-making processes, reshaping business operations, and creating new opportunities for growth.
#
# ## 6. Continual Learning
#
# New architectures in machine learning are being designed to support continual learning—where models continuously learn from new data without losing knowledge from previous tasks. This approach significantly reduces the costs associated with retraining and enhances the model's adaptability to changing environments. Techniques such as Elastic Weight Consolidation (EWC) and online learning frameworks allow models to integrate new knowledge while maintaining performance across previously learned tasks. This innovation enhances the ability of LLMs to remain relevant in fast-paced and evolving data environments, thus improving their utility in real-world applications.
#
# ## 7. Environmental Impact Consideration
#
# The ecological footprint of training large language models is becoming a pivotal concern within the AI community. Researchers are increasingly motivated to enhance energy efficiency through strategies including knowledge distillation, which reduces model size while preserving capability, and model pruning, which removes unnecessary parameters. Additionally, organizations are exploring carbon credits and offset strategies to balance their environmental impact. These initiatives signify a growing awareness of the responsibilities that come with deploying powerful AI models and the importance of pursuing sustainable practices in AI development.
#
# ## 8. Open Source Movement
#
# The rise of open-source language models such as Hugging Face's Transformers and EleutherAI’s GPT-Neo has democratized access to advanced natural language processing capabilities. This movement encourages collaboration and innovation by allowing researchers and developers worldwide to contribute to the advancement of AI technologies. As a result, organizations of varying sizes can leverage these robust tools to build customized applications suited to their needs without the high costs typically associated with proprietary technologies. The open-source ethos fosters a sense of community and shared knowledge, accelerating the pace of innovation in the field.
#
# ## 9. Regulatory Developments
#
# As LLMs proliferate, regulatory bodies are becoming increasingly vigilant about their applications. Governments are beginning to draft regulations focusing on ethical AI usage, data privacy, and transparency. These guided frameworks urge companies to be accountable for the AI systems they deploy, ensuring alignment with ethical standards. The need for clear guidelines emerges from societal concerns regarding misuse and the potential risks posed by AI technologies. Adhering to regulatory frameworks will be vital for organizations looking to maintain public trust while innovating responsibly.
#
# ## 10. Human-AI Collaboration
#
# Advancements in AI LLMs are fostering a new era of human-AI collaboration, redefining how these technologies assist in creative tasks, decision-making, and problem-solving. Models are being engineered to complement human abilities, enabling a symbiotic relationship between human intelligence and machine capabilities. This trend highlights the potential of LLMs to enhance human creativity and streamline complex processes rather than merely automating them. Such collaboration can lead to more innovative outcomes and improved efficiency across various domains, spanning industries from healthcare to creative arts.
#
# By synthesizing these developments, it is evident that the landscape of AI language models is rapidly evolving. The implications of these changes span technology, ethics, industry practices, and societal impacts, heralding a new era of artificial intelligence that is more efficient, accessible, and responsible.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
