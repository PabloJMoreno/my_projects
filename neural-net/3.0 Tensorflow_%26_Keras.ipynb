# %% [markdown]
# <p><img alt="Colaboratory logo" height="55px" src="https://www.gstatic.com/devrel-devsite/prod/vf0396724755d04dbab75050e6812ced8fb2ab11d424163deba5826536b4b1964/tensorflow/images/lockup.svg" align="left" hspace="10px" vspace="0px"></p>
#
# <p><img alt="Colaboratory logo" height="55px" src="https://keras.io/img/logo.png" align="left" hspace="10px" vspace="0px"></p>

# %% [markdown]
# Table of contents:
# - [Tensorflow & Keras](#TF-KS)
# - [Dataset](#Dataset)
# - [Training](#Training)

# %% [markdown]
# <a name="TF-KS"></a>
# ## **Tensorflow and Keras**

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# <a name="Dataset"></a>
# ## **Dataset**

# %% [markdown]
# > Used Cars
# <p><img alt="Colaboratory logo" height="55px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/GAZ-24_Volga.svg/640px-GAZ-24_Volga.svg.png" align="left" hspace="10px" vspace="0px"></p>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
data = pd.read_csv("/content/drive/My Drive/ann_used_cars.csv", usecols=["mileage", 'year', "price"])
data.head()
# Out:
#    mileage  year  price
# 0     7413  2011  21992
# 1    10926  2011  20995
# 2     7351  2011  19995
# 3    11613  2011  17809
# 4     8367  2012  17500

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['mileage','year']], data['price'], test_size=0.3, random_state=42)

# %% [markdown]
# <a name="Training"></a>
# ## **Training**

# %% [markdown]
# <a href="https://ibb.co/gV2rqgz"><img src="https://i.ibb.co/FVrhZ7g/bias-weights2.png" alt="bias-weights2" border="0"></a>

# %%
from tensorflow.keras.layers import Dense, Input, InputLayer

model = tf.keras.Sequential()
model.add(InputLayer(input_shape=2))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=100, verbose=True, validation_split=0.1)
print("Finished training the model")
# Out:
# Epoch 1/100
# 3/3 [==============================] - 3s 89ms/step - loss: 1753324672.0000 - val_loss: 1542265216.0000
# Epoch 2/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1729250688.0000 - val_loss: 1525233536.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1710453632.0000 - val_loss: 1510518272.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1694245760.0000 - val_loss: 1496928128.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1679317760.0000 - val_loss: 1484553472.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1665578752.0000 - val_loss: 1472474368.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1651958784.0000 - val_loss: 1461090304.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1639057792.0000 - val_loss: 1449737600.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1626242560.0000 - val_loss: 1438551680.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1613704448.0000 - val_loss: 1427588992.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1601291520.0000 - val_loss: 1416811136.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1588983424.0000 - val_loss: 1405979136.0000
# Epoch 13/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1576842880.0000 - val_loss: 1395174784.0000
# Epoch 14/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1564803200.0000 - val_loss: 1384906368.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1552861056.0000 - val_loss: 1374308224.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1540865024.0000 - val_loss: 1363565568.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1528824832.0000 - val_loss: 1353285376.0000
# Epoch 18/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1517260160.0000 - val_loss: 1342747136.0000
# Epoch 19/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1505378816.0000 - val_loss: 1332508416.0000
# Epoch 20/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1493710464.0000 - val_loss: 1322662784.0000
# Epoch 21/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1482447616.0000 - val_loss: 1312519552.0000
# Epoch 22/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1471053312.0000 - val_loss: 1302655744.0000
# Epoch 23/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1459761280.0000 - val_loss: 1292636672.0000
# Epoch 24/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1448558464.0000 - val_loss: 1282798464.0000
# Epoch 25/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1437284224.0000 - val_loss: 1272782976.0000
# Epoch 26/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1426015488.0000 - val_loss: 1262688000.0000
# Epoch 27/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1414503296.0000 - val_loss: 1252846464.0000
# Epoch 28/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1403224960.0000 - val_loss: 1242751488.0000
# Epoch 29/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1391789824.0000 - val_loss: 1232796288.0000
# Epoch 30/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1380646784.0000 - val_loss: 1222950784.0000
# Epoch 31/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1369380608.0000 - val_loss: 1213023872.0000
# Epoch 32/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1358160512.0000 - val_loss: 1203294464.0000
# Epoch 33/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1347091840.0000 - val_loss: 1193533312.0000
# Epoch 34/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1336070016.0000 - val_loss: 1183760512.0000
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1325268096.0000 - val_loss: 1174474624.0000
# Epoch 36/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1314477184.0000 - val_loss: 1164888960.0000
# Epoch 37/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1303659392.0000 - val_loss: 1155396480.0000
# Epoch 38/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1293047552.0000 - val_loss: 1146096128.0000
# Epoch 39/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1282408320.0000 - val_loss: 1136676224.0000
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1271604352.0000 - val_loss: 1127166848.0000
# Epoch 41/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1260802688.0000 - val_loss: 1117572736.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1250199424.0000 - val_loss: 1108426240.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1239700608.0000 - val_loss: 1099188608.0000
# Epoch 44/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1229401472.0000 - val_loss: 1090025600.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1218846336.0000 - val_loss: 1080685696.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1208233216.0000 - val_loss: 1071590016.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1198078976.0000 - val_loss: 1062712896.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1187809280.0000 - val_loss: 1053538688.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1177701120.0000 - val_loss: 1044739520.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1167889280.0000 - val_loss: 1036095296.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1157741696.0000 - val_loss: 1027071616.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1147581312.0000 - val_loss: 1018131712.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1137501696.0000 - val_loss: 1009517504.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1127664768.0000 - val_loss: 1000844224.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1117785344.0000 - val_loss: 992116800.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1107869952.0000 - val_loss: 983371840.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1098061568.0000 - val_loss: 974765056.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1088394752.0000 - val_loss: 966307584.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1079142912.0000 - val_loss: 958104640.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1069461056.0000 - val_loss: 949658176.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1059762240.0000 - val_loss: 941059712.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1050118528.0000 - val_loss: 932531008.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1040390784.0000 - val_loss: 924075840.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1030848704.0000 - val_loss: 915565120.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1021212864.0000 - val_loss: 907262208.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1011910336.0000 - val_loss: 899166976.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1002842176.0000 - val_loss: 891182848.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 12ms/step - loss: 993840000.0000 - val_loss: 883170048.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 12ms/step - loss: 984715200.0000 - val_loss: 875240000.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 12ms/step - loss: 975568192.0000 - val_loss: 867161920.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 966748224.0000 - val_loss: 859431936.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 25ms/step - loss: 957587264.0000 - val_loss: 851316480.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 13ms/step - loss: 948451648.0000 - val_loss: 843332352.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 20ms/step - loss: 939384768.0000 - val_loss: 835329280.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 15ms/step - loss: 930307072.0000 - val_loss: 827349056.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 13ms/step - loss: 921419968.0000 - val_loss: 819496512.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 14ms/step - loss: 912528064.0000 - val_loss: 811808000.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 13ms/step - loss: 903913024.0000 - val_loss: 803966400.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 13ms/step - loss: 894939648.0000 - val_loss: 796442048.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 14ms/step - loss: 886400448.0000 - val_loss: 788707584.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 13ms/step - loss: 877712576.0000 - val_loss: 781298880.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 16ms/step - loss: 869195072.0000 - val_loss: 773759552.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 13ms/step - loss: 860651456.0000 - val_loss: 766214208.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 13ms/step - loss: 852217344.0000 - val_loss: 758880256.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 12ms/step - loss: 844080576.0000 - val_loss: 751647040.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 13ms/step - loss: 835676736.0000 - val_loss: 744181696.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 14ms/step - loss: 827380992.0000 - val_loss: 737158336.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 13ms/step - loss: 819220480.0000 - val_loss: 729858304.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 13ms/step - loss: 811176704.0000 - val_loss: 722807872.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 13ms/step - loss: 803006528.0000 - val_loss: 715611712.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 794907264.0000 - val_loss: 708515456.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 12ms/step - loss: 786742080.0000 - val_loss: 701235136.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 13ms/step - loss: 778582208.0000 - val_loss: 694042240.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 13ms/step - loss: 770632576.0000 - val_loss: 687237184.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 13ms/step - loss: 762834880.0000 - val_loss: 680368128.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 12ms/step - loss: 755054720.0000 - val_loss: 673515584.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 12ms/step - loss: 747558592.0000 - val_loss: 666528384.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 13ms/step - loss: 739441536.0000 - val_loss: 659854912.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 13ms/step - loss: 731979328.0000 - val_loss: 653493440.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 724855680.0000 - val_loss: 646963776.0000
# Finished training the model

# %% [markdown]
# <a href="https://ibb.co/gV2rqgz"><img src="https://i.ibb.co/FVrhZ7g/bias-weights2.png" alt="bias-weights2" border="0"></a>

# %%
# Weight
model.layers[0].get_weights()[0]
# Out:
# array([[ 0.70059246],
#        [-1.1640834 ]], dtype=float32)

# %%
# Bias
model.layers[0].get_weights()[1]
# Out:
# array([-0.2992233], dtype=float32)

# %%
y_pred = model.predict(X_test)
print('Predicted Values', y_pred[0:5].round().tolist())
print('Actual Values', y_test[0:5].tolist())
# Out:
# Predicted Values [[16947.0], [5829.0], [51771.0], [21832.0], [42538.0]]
# Actual Values [13663, 15992, 10815, 13383, 13425]

# %%
# Accuracy (Root Mean Squared Error)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 26305.365153181898
